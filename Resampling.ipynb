# %%
import os
import pandas as pd

def find_min_shape(csv_dir):
    """
    Find the minimum number of rows and columns across all CSV files in the specified directory and its subdirectories.

    Parameters:
    csv_dir (str): Directory containing the CSV files and subdirectories.

    Returns:
    tuple: A tuple containing the minimum number of rows and columns (min_rows, min_cols).
    """
    min_rows = float('inf')
    min_cols = float('inf')

    # Walk through the directory and its subdirectories
    for root, dirs, files in os.walk(csv_dir):
        for file in files:
            if file.endswith('.csv'):
                csv_path = os.path.join(root, file)
                
                try:
                    # Read the CSV file
                    df = pd.read_csv(csv_path)

                    # Update minimum rows and columns
                    rows, cols = df.shape
                    if rows < min_rows:
                        min_rows = rows
                    if cols < min_cols:
                        min_cols = cols
                except Exception as e:
                    print(f"Failed to process {csv_path}: {e}")

    return min_rows, min_cols

def normalize_csv_data(csv_dir, min_rows, min_cols):
    """
    Normalize all CSV files in the specified directory and its subdirectories by truncating them to the minimum number of rows and columns.

    Parameters:
    csv_dir (str): Directory containing the CSV files and subdirectories.
    min_rows (int): Minimum number of rows to normalize to.
    min_cols (int): Minimum number of columns to normalize to.
    """
    # Walk through the directory and its subdirectories
    for root, dirs, files in os.walk(csv_dir):
        for file in files:
            if file.endswith('.csv'):
                csv_path = os.path.join(root, file)
                
                try:
                    # Read the CSV file
                    df = pd.read_csv(csv_path)

                    # Normalize the DataFrame by truncating rows and columns
                    normalized_df = df.iloc[:min_rows, :min_cols]

                    # Save the normalized DataFrame back to CSV
                    normalized_df.to_csv(csv_path, index=False)
                    print(f"Normalized {csv_path} to {min_rows} rows and {min_cols} columns")
                except Exception as e:
                    print(f"Failed to process {csv_path}: {e}")

# %%
# Example usage:
csv_directory = "Datacsv"
min_rows, min_cols = find_min_shape(csv_directory)
normalize_csv_data(csv_directory, min_rows, min_cols)
# Out:
# Normalized Datacsv\ADHD\v10p_v10p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v12p_v12p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v14p_v14p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v15p_v15p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v173_v173.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v177_v177.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v179_v179.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v181_v181.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v183_v183.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v18p_v18p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v190_v190.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v196_v196.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v198_v198.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v19p_v19p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v1p_v1p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v200_v200.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v204_v204.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v206_v206.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v209_v209.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v20p_v20p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v213_v213.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v215_v215.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v219_v219.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v21p_v21p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v227_v227.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v22p_v22p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v231_v231.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v234_v234.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v236_v236.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v238_v238.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v244_v244.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v246_v246.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v24p_v24p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v250_v250.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v254_v254.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v25p_v25p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v263_v263.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v265_v265.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v270_v270.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v274_v274.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v279_v279.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v27p_v27p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v284_v284.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v286_v286.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v288_v288.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v28p_v28p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v29p_v29p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v30p_v30p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v31p_v31p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v32p_v32p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v33p_v33p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v34p_v34p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v35p_v35p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v36p_v36p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v37p_v37p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v38p_v38p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v39p_v39p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v3p_v3p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v40p_v40p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v6p_v6p.csv to 7983 rows and 19 columns
# Normalized Datacsv\ADHD\v8p_v8p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v107_v107.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v108_v108.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v109_v109.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v110_v110.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v111_v111.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v112_v112.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v113_v113.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v114_v114.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v115_v115.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v116_v116.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v117_v117.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v118_v118.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v120_v120.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v121_v121.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v123_v123.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v125_v125.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v127_v127.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v129_v129.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v131_v131.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v133_v133.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v134_v134.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v138_v138.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v140_v140.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v143_v143.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v147_v147.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v149_v149.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v151_v151.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v297_v297.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v298_v298.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v299_v299.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v300_v300.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v302_v302.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v303_v303.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v304_v304.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v305_v305.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v306_v306.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v307_v307.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v308_v308.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v309_v309.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v310_v310.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v41p_v41p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v42p_v42p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v43p_v43p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v44p_v44p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v45p_v45p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v46p_v46p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v47p_v47p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v48p_v48p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v49p_v49p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v50p_v50p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v51p_v51p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v52p_v52p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v53p_v53p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v54p_v54p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v55p_v55p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v56p_v56p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v57p_v57p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v58p_v58p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v59p_v59p.csv to 7983 rows and 19 columns
# Normalized Datacsv\Control\v60p_v60p.csv to 7983 rows and 19 columns
