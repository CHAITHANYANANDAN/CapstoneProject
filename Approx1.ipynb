# %%
import numpy as np
import pandas as pd
from numba import jit
import os

# Optimized Approximate Entropy function with Numba JIT and sliding window
@jit(nopython=True)
def approximate_entropy(U, m, r):
    """
    Compute Approximate Entropy (ApEn) of a time series in a memory-efficient way.
    
    Parameters:
    U : array-like
        The input signal.
    m : int
        The length of compared run of data.
    r : float
        The filtering level (standard deviation * r).
    
    Returns:
    float
        Approximate entropy of the input signal.
    """
    def _phi(m):
        N = len(U)
        count = 0
        for i in range(N - m):
            template = U[i:i + m]
            matches = 0
            for j in range(N - m):
                candidate = U[j:j + m]
                if np.max(np.abs(template - candidate)) <= r:
                    matches += 1
            count += np.log(matches / (N - m + 1))
        return count / (N - m + 1)

    return abs(_phi(m) - _phi(m + 1))

# Sliding window function for Approximate Entropy
def calculate_apen_sliding_window(signal, m=2, r_factor=0.2, window_size=128, step_size=64):
    """
    Compute Approximate Entropy using a sliding window approach.
    
    Parameters:
    signal : array-like
        The input signal (EEG data).
    m : int
        The embedding dimension.
    r_factor : float
        The factor to calculate the tolerance level (r = r_factor * std).
    window_size : int
        Size of the sliding window (number of samples).
    step_size : int
        Step size for the sliding window (how many samples to shift).
    
    Returns:
    array
        Approximate entropy for each window.
    """
    r = r_factor * np.std(signal)  # Set r based on the standard deviation of the signal
    apen_values = []

    # Slide the window across the signal
    for start in range(0, len(signal) - window_size + 1, step_size):
        window = signal[start:start + window_size]
        apen_value = approximate_entropy(window, m=m, r=r)
        apen_values.append(apen_value)

    return np.array(apen_values)

# Function to read and process large EEG data in chunks if needed
def calculate_apen_for_large_data(preprocessed_file, eeg_channel, output_directory, m=2, r_factor=0.2, window_size=128, step_size=64, chunksize=100000):
    """
    Compute Approximate Entropy for large EEG data using sliding windows and chunk processing.
    
    Parameters:
    preprocessed_file : str
        Path to the preprocessed EEG CSV file.
    eeg_channel : str
        Name of the EEG channel column in the CSV file.
    output_directory : str
        Directory to save the output CSV file.
    m : int
        Embedding dimension for ApEn calculation.
    r_factor : float
        Tolerance factor.
    window_size : int
        Size of sliding window.
    step_size : int
        Step size for sliding window.
    chunksize : int
        Number of samples to read at a time from the file.
    
    Returns:
    array
        Approximate entropy for each window in the large dataset.
    """
    apen_values = []
    patient_id = None
    label = None

    # Load data in chunks to avoid memory overload
    for chunk in pd.read_csv(preprocessed_file, chunksize=chunksize):
        signal = chunk[eeg_channel].values
        
        # Capture Patient_ID and Label only once
        if patient_id is None:
            patient_id = chunk['Patient_ID'].iloc[0]
            label = chunk['Label'].iloc[0]
        
        apen_chunk_values = calculate_apen_sliding_window(signal, m, r_factor, window_size, step_size)
        apen_values.extend(apen_chunk_values)

    # Prepare the results in a DataFrame
    apen_df = pd.DataFrame({
        'Patient_ID': [patient_id] * len(apen_values),
        'Label': [label] * len(apen_values),
        'ApEn_Values': apen_values
    })
    
    # Create the output directory if it does not exist
    os.makedirs(output_directory, exist_ok=True)
    
    # Save to CSV in the specified output directory
    output_file = os.path.join(output_directory, f'approx_entropy_{patient_id}.csv')
    apen_df.to_csv(output_file, index=False)
    print(f"Approximate Entropy values saved to {output_file}")

# %%
# Example usage
if __name__ == "__main__":
    preprocessed_file = 'preprocessed_eeg_data.csv'
    eeg_channel = 'Fz'  # Specify the EEG channel, e.g., 'Cz', 'Fz', etc.
    output_directory = 'ApproximatedForSingle'  # Specify the output directory

    calculate_apen_for_large_data(preprocessed_file, eeg_channel, output_directory, m=2, r_factor=0.2, window_size=128, step_size=64)
# Out:
# Approximate Entropy values saved to ApproximatedForSingle\approx_entropy_v10p_v10p.csv.csv

# %%
# Function to calculate Approximate Entropy for all patients
def calculate_apen_for_all_patients(preprocessed_file, output_directory, m=2, r_factor=0.2, window_size=128, step_size=64):
    # Ensure the output directory exists
    os.makedirs(output_directory, exist_ok=True)
    
    # Load the preprocessed EEG data
    df = pd.read_csv(preprocessed_file)

    # Iterate through each patient in the DataFrame
    unique_patients = df['Patient_ID'].unique()
    for patient_id in unique_patients:
        patient_data = df[df['Patient_ID'] == patient_id]

        # Assuming all EEG channels are columns except 'Label' and 'Patient_ID'
        eeg_columns = [col for col in patient_data.columns if col not in ['Label', 'Patient_ID']]
        
        # Calculate ApEn for each EEG channel and store results
        results = []
        for col in eeg_columns:
            signal = patient_data[col].values
            apen_values = calculate_apen_sliding_window(signal, m=m, r_factor=r_factor, window_size=window_size, step_size=step_size)
            for apen_value in apen_values:
                results.append({'Patient_ID': patient_id, 'Label': patient_data['Label'].values[0], 'ApEn': apen_value})
        
        # Convert results to DataFrame and save to CSV
        results_df = pd.DataFrame(results)
        output_file = os.path.join(output_directory, f'approx_entropy_patient_{patient_id}.csv')
        results_df.to_csv(output_file, index=False)
        print(f"Approximate Entropy results for Patient {patient_id} saved to {output_file}")

# %%
# Example usage
if __name__ == "__main__":
    preprocessed_file = 'preprocessed_eeg_data.csv'  
    output_directory = 'ApproximatedForSingle'  
    calculate_apen_for_all_patients(preprocessed_file, output_directory, window_size=128, step_size=64)
# Out:
# Approximate Entropy results for Patient v10p_v10p.csv saved to ApproximatedForSingle\approx_entropy_patient_v10p_v10p.csv.csv
# Approximate Entropy results for Patient v12p_v12p.csv saved to ApproximatedForSingle\approx_entropy_patient_v12p_v12p.csv.csv
# Approximate Entropy results for Patient v14p_v14p.csv saved to ApproximatedForSingle\approx_entropy_patient_v14p_v14p.csv.csv
# Approximate Entropy results for Patient v15p_v15p.csv saved to ApproximatedForSingle\approx_entropy_patient_v15p_v15p.csv.csv
# Approximate Entropy results for Patient v173_v173.csv saved to ApproximatedForSingle\approx_entropy_patient_v173_v173.csv.csv
# Approximate Entropy results for Patient v177_v177.csv saved to ApproximatedForSingle\approx_entropy_patient_v177_v177.csv.csv
# Approximate Entropy results for Patient v179_v179.csv saved to ApproximatedForSingle\approx_entropy_patient_v179_v179.csv.csv
# Approximate Entropy results for Patient v181_v181.csv saved to ApproximatedForSingle\approx_entropy_patient_v181_v181.csv.csv
# Approximate Entropy results for Patient v183_v183.csv saved to ApproximatedForSingle\approx_entropy_patient_v183_v183.csv.csv
# Approximate Entropy results for Patient v18p_v18p.csv saved to ApproximatedForSingle\approx_entropy_patient_v18p_v18p.csv.csv
# Approximate Entropy results for Patient v190_v190.csv saved to ApproximatedForSingle\approx_entropy_patient_v190_v190.csv.csv
# Approximate Entropy results for Patient v196_v196.csv saved to ApproximatedForSingle\approx_entropy_patient_v196_v196.csv.csv
# Approximate Entropy results for Patient v198_v198.csv saved to ApproximatedForSingle\approx_entropy_patient_v198_v198.csv.csv
# Approximate Entropy results for Patient v19p_v19p.csv saved to ApproximatedForSingle\approx_entropy_patient_v19p_v19p.csv.csv
# Approximate Entropy results for Patient v1p_v1p.csv saved to ApproximatedForSingle\approx_entropy_patient_v1p_v1p.csv.csv
# Approximate Entropy results for Patient v200_v200.csv saved to ApproximatedForSingle\approx_entropy_patient_v200_v200.csv.csv
# Approximate Entropy results for Patient v204_v204.csv saved to ApproximatedForSingle\approx_entropy_patient_v204_v204.csv.csv
# Approximate Entropy results for Patient v206_v206.csv saved to ApproximatedForSingle\approx_entropy_patient_v206_v206.csv.csv
# Approximate Entropy results for Patient v209_v209.csv saved to ApproximatedForSingle\approx_entropy_patient_v209_v209.csv.csv
# Approximate Entropy results for Patient v20p_v20p.csv saved to ApproximatedForSingle\approx_entropy_patient_v20p_v20p.csv.csv
# Approximate Entropy results for Patient v213_v213.csv saved to ApproximatedForSingle\approx_entropy_patient_v213_v213.csv.csv
# Approximate Entropy results for Patient v215_v215.csv saved to ApproximatedForSingle\approx_entropy_patient_v215_v215.csv.csv
# Approximate Entropy results for Patient v219_v219.csv saved to ApproximatedForSingle\approx_entropy_patient_v219_v219.csv.csv
# Approximate Entropy results for Patient v21p_v21p.csv saved to ApproximatedForSingle\approx_entropy_patient_v21p_v21p.csv.csv
# Approximate Entropy results for Patient v227_v227.csv saved to ApproximatedForSingle\approx_entropy_patient_v227_v227.csv.csv
# Approximate Entropy results for Patient v22p_v22p.csv saved to ApproximatedForSingle\approx_entropy_patient_v22p_v22p.csv.csv
# Approximate Entropy results for Patient v231_v231.csv saved to ApproximatedForSingle\approx_entropy_patient_v231_v231.csv.csv
# Approximate Entropy results for Patient v234_v234.csv saved to ApproximatedForSingle\approx_entropy_patient_v234_v234.csv.csv
# Approximate Entropy results for Patient v236_v236.csv saved to ApproximatedForSingle\approx_entropy_patient_v236_v236.csv.csv
# Approximate Entropy results for Patient v238_v238.csv saved to ApproximatedForSingle\approx_entropy_patient_v238_v238.csv.csv
# Approximate Entropy results for Patient v244_v244.csv saved to ApproximatedForSingle\approx_entropy_patient_v244_v244.csv.csv
# Approximate Entropy results for Patient v246_v246.csv saved to ApproximatedForSingle\approx_entropy_patient_v246_v246.csv.csv
# Approximate Entropy results for Patient v24p_v24p.csv saved to ApproximatedForSingle\approx_entropy_patient_v24p_v24p.csv.csv
# Approximate Entropy results for Patient v250_v250.csv saved to ApproximatedForSingle\approx_entropy_patient_v250_v250.csv.csv
# Approximate Entropy results for Patient v254_v254.csv saved to ApproximatedForSingle\approx_entropy_patient_v254_v254.csv.csv
# Approximate Entropy results for Patient v25p_v25p.csv saved to ApproximatedForSingle\approx_entropy_patient_v25p_v25p.csv.csv
# Approximate Entropy results for Patient v263_v263.csv saved to ApproximatedForSingle\approx_entropy_patient_v263_v263.csv.csv
# Approximate Entropy results for Patient v265_v265.csv saved to ApproximatedForSingle\approx_entropy_patient_v265_v265.csv.csv
# Approximate Entropy results for Patient v270_v270.csv saved to ApproximatedForSingle\approx_entropy_patient_v270_v270.csv.csv
# Approximate Entropy results for Patient v274_v274.csv saved to ApproximatedForSingle\approx_entropy_patient_v274_v274.csv.csv
# Approximate Entropy results for Patient v279_v279.csv saved to ApproximatedForSingle\approx_entropy_patient_v279_v279.csv.csv
# Approximate Entropy results for Patient v27p_v27p.csv saved to ApproximatedForSingle\approx_entropy_patient_v27p_v27p.csv.csv
# Approximate Entropy results for Patient v284_v284.csv saved to ApproximatedForSingle\approx_entropy_patient_v284_v284.csv.csv
# Approximate Entropy results for Patient v286_v286.csv saved to ApproximatedForSingle\approx_entropy_patient_v286_v286.csv.csv
# Approximate Entropy results for Patient v288_v288.csv saved to ApproximatedForSingle\approx_entropy_patient_v288_v288.csv.csv
# Approximate Entropy results for Patient v28p_v28p.csv saved to ApproximatedForSingle\approx_entropy_patient_v28p_v28p.csv.csv
# Approximate Entropy results for Patient v29p_v29p.csv saved to ApproximatedForSingle\approx_entropy_patient_v29p_v29p.csv.csv
# Approximate Entropy results for Patient v30p_v30p.csv saved to ApproximatedForSingle\approx_entropy_patient_v30p_v30p.csv.csv
# Approximate Entropy results for Patient v31p_v31p.csv saved to ApproximatedForSingle\approx_entropy_patient_v31p_v31p.csv.csv
# Approximate Entropy results for Patient v32p_v32p.csv saved to ApproximatedForSingle\approx_entropy_patient_v32p_v32p.csv.csv
# Approximate Entropy results for Patient v33p_v33p.csv saved to ApproximatedForSingle\approx_entropy_patient_v33p_v33p.csv.csv
# Approximate Entropy results for Patient v34p_v34p.csv saved to ApproximatedForSingle\approx_entropy_patient_v34p_v34p.csv.csv
# Approximate Entropy results for Patient v35p_v35p.csv saved to ApproximatedForSingle\approx_entropy_patient_v35p_v35p.csv.csv
# Approximate Entropy results for Patient v36p_v36p.csv saved to ApproximatedForSingle\approx_entropy_patient_v36p_v36p.csv.csv
# Approximate Entropy results for Patient v37p_v37p.csv saved to ApproximatedForSingle\approx_entropy_patient_v37p_v37p.csv.csv
# Approximate Entropy results for Patient v38p_v38p.csv saved to ApproximatedForSingle\approx_entropy_patient_v38p_v38p.csv.csv
# Approximate Entropy results for Patient v39p_v39p.csv saved to ApproximatedForSingle\approx_entropy_patient_v39p_v39p.csv.csv
# Approximate Entropy results for Patient v3p_v3p.csv saved to ApproximatedForSingle\approx_entropy_patient_v3p_v3p.csv.csv
# Approximate Entropy results for Patient v40p_v40p.csv saved to ApproximatedForSingle\approx_entropy_patient_v40p_v40p.csv.csv
# Approximate Entropy results for Patient v6p_v6p.csv saved to ApproximatedForSingle\approx_entropy_patient_v6p_v6p.csv.csv
# Approximate Entropy results for Patient v8p_v8p.csv saved to ApproximatedForSingle\approx_entropy_patient_v8p_v8p.csv.csv
# Approximate Entropy results for Patient v107_v107.csv saved to ApproximatedForSingle\approx_entropy_patient_v107_v107.csv.csv
# Approximate Entropy results for Patient v108_v108.csv saved to ApproximatedForSingle\approx_entropy_patient_v108_v108.csv.csv
# Approximate Entropy results for Patient v109_v109.csv saved to ApproximatedForSingle\approx_entropy_patient_v109_v109.csv.csv
# Approximate Entropy results for Patient v110_v110.csv saved to ApproximatedForSingle\approx_entropy_patient_v110_v110.csv.csv
# Approximate Entropy results for Patient v111_v111.csv saved to ApproximatedForSingle\approx_entropy_patient_v111_v111.csv.csv
# Approximate Entropy results for Patient v112_v112.csv saved to ApproximatedForSingle\approx_entropy_patient_v112_v112.csv.csv
# Approximate Entropy results for Patient v113_v113.csv saved to ApproximatedForSingle\approx_entropy_patient_v113_v113.csv.csv
# Approximate Entropy results for Patient v114_v114.csv saved to ApproximatedForSingle\approx_entropy_patient_v114_v114.csv.csv
# Approximate Entropy results for Patient v115_v115.csv saved to ApproximatedForSingle\approx_entropy_patient_v115_v115.csv.csv
# Approximate Entropy results for Patient v116_v116.csv saved to ApproximatedForSingle\approx_entropy_patient_v116_v116.csv.csv
# Approximate Entropy results for Patient v117_v117.csv saved to ApproximatedForSingle\approx_entropy_patient_v117_v117.csv.csv
# Approximate Entropy results for Patient v118_v118.csv saved to ApproximatedForSingle\approx_entropy_patient_v118_v118.csv.csv
# Approximate Entropy results for Patient v120_v120.csv saved to ApproximatedForSingle\approx_entropy_patient_v120_v120.csv.csv
# Approximate Entropy results for Patient v121_v121.csv saved to ApproximatedForSingle\approx_entropy_patient_v121_v121.csv.csv
# Approximate Entropy results for Patient v123_v123.csv saved to ApproximatedForSingle\approx_entropy_patient_v123_v123.csv.csv
# Approximate Entropy results for Patient v125_v125.csv saved to ApproximatedForSingle\approx_entropy_patient_v125_v125.csv.csv
# Approximate Entropy results for Patient v127_v127.csv saved to ApproximatedForSingle\approx_entropy_patient_v127_v127.csv.csv
# Approximate Entropy results for Patient v129_v129.csv saved to ApproximatedForSingle\approx_entropy_patient_v129_v129.csv.csv
# Approximate Entropy results for Patient v131_v131.csv saved to ApproximatedForSingle\approx_entropy_patient_v131_v131.csv.csv
# Approximate Entropy results for Patient v133_v133.csv saved to ApproximatedForSingle\approx_entropy_patient_v133_v133.csv.csv
# Approximate Entropy results for Patient v134_v134.csv saved to ApproximatedForSingle\approx_entropy_patient_v134_v134.csv.csv
# Approximate Entropy results for Patient v138_v138.csv saved to ApproximatedForSingle\approx_entropy_patient_v138_v138.csv.csv
# Approximate Entropy results for Patient v140_v140.csv saved to ApproximatedForSingle\approx_entropy_patient_v140_v140.csv.csv
# Approximate Entropy results for Patient v143_v143.csv saved to ApproximatedForSingle\approx_entropy_patient_v143_v143.csv.csv
# Approximate Entropy results for Patient v147_v147.csv saved to ApproximatedForSingle\approx_entropy_patient_v147_v147.csv.csv
# Approximate Entropy results for Patient v149_v149.csv saved to ApproximatedForSingle\approx_entropy_patient_v149_v149.csv.csv
# Approximate Entropy results for Patient v151_v151.csv saved to ApproximatedForSingle\approx_entropy_patient_v151_v151.csv.csv
# Approximate Entropy results for Patient v297_v297.csv saved to ApproximatedForSingle\approx_entropy_patient_v297_v297.csv.csv
# Approximate Entropy results for Patient v298_v298.csv saved to ApproximatedForSingle\approx_entropy_patient_v298_v298.csv.csv
# Approximate Entropy results for Patient v299_v299.csv saved to ApproximatedForSingle\approx_entropy_patient_v299_v299.csv.csv
# Approximate Entropy results for Patient v300_v300.csv saved to ApproximatedForSingle\approx_entropy_patient_v300_v300.csv.csv
# Approximate Entropy results for Patient v302_v302.csv saved to ApproximatedForSingle\approx_entropy_patient_v302_v302.csv.csv
# Approximate Entropy results for Patient v303_v303.csv saved to ApproximatedForSingle\approx_entropy_patient_v303_v303.csv.csv
# Approximate Entropy results for Patient v304_v304.csv saved to ApproximatedForSingle\approx_entropy_patient_v304_v304.csv.csv
# Approximate Entropy results for Patient v305_v305.csv saved to ApproximatedForSingle\approx_entropy_patient_v305_v305.csv.csv
# Approximate Entropy results for Patient v306_v306.csv saved to ApproximatedForSingle\approx_entropy_patient_v306_v306.csv.csv
# Approximate Entropy results for Patient v307_v307.csv saved to ApproximatedForSingle\approx_entropy_patient_v307_v307.csv.csv
# Approximate Entropy results for Patient v308_v308.csv saved to ApproximatedForSingle\approx_entropy_patient_v308_v308.csv.csv
# Approximate Entropy results for Patient v309_v309.csv saved to ApproximatedForSingle\approx_entropy_patient_v309_v309.csv.csv
# Approximate Entropy results for Patient v310_v310.csv saved to ApproximatedForSingle\approx_entropy_patient_v310_v310.csv.csv
# Approximate Entropy results for Patient v41p_v41p.csv saved to ApproximatedForSingle\approx_entropy_patient_v41p_v41p.csv.csv
# Approximate Entropy results for Patient v42p_v42p.csv saved to ApproximatedForSingle\approx_entropy_patient_v42p_v42p.csv.csv
# Approximate Entropy results for Patient v43p_v43p.csv saved to ApproximatedForSingle\approx_entropy_patient_v43p_v43p.csv.csv
# Approximate Entropy results for Patient v44p_v44p.csv saved to ApproximatedForSingle\approx_entropy_patient_v44p_v44p.csv.csv
# Approximate Entropy results for Patient v45p_v45p.csv saved to ApproximatedForSingle\approx_entropy_patient_v45p_v45p.csv.csv
# Approximate Entropy results for Patient v46p_v46p.csv saved to ApproximatedForSingle\approx_entropy_patient_v46p_v46p.csv.csv
# Approximate Entropy results for Patient v47p_v47p.csv saved to ApproximatedForSingle\approx_entropy_patient_v47p_v47p.csv.csv
# Approximate Entropy results for Patient v48p_v48p.csv saved to ApproximatedForSingle\approx_entropy_patient_v48p_v48p.csv.csv
# Approximate Entropy results for Patient v49p_v49p.csv saved to ApproximatedForSingle\approx_entropy_patient_v49p_v49p.csv.csv
# Approximate Entropy results for Patient v50p_v50p.csv saved to ApproximatedForSingle\approx_entropy_patient_v50p_v50p.csv.csv
# Approximate Entropy results for Patient v51p_v51p.csv saved to ApproximatedForSingle\approx_entropy_patient_v51p_v51p.csv.csv
# Approximate Entropy results for Patient v52p_v52p.csv saved to ApproximatedForSingle\approx_entropy_patient_v52p_v52p.csv.csv
# Approximate Entropy results for Patient v53p_v53p.csv saved to ApproximatedForSingle\approx_entropy_patient_v53p_v53p.csv.csv
# Approximate Entropy results for Patient v54p_v54p.csv saved to ApproximatedForSingle\approx_entropy_patient_v54p_v54p.csv.csv
# Approximate Entropy results for Patient v55p_v55p.csv saved to ApproximatedForSingle\approx_entropy_patient_v55p_v55p.csv.csv
# Approximate Entropy results for Patient v56p_v56p.csv saved to ApproximatedForSingle\approx_entropy_patient_v56p_v56p.csv.csv
# Approximate Entropy results for Patient v57p_v57p.csv saved to ApproximatedForSingle\approx_entropy_patient_v57p_v57p.csv.csv
# Approximate Entropy results for Patient v58p_v58p.csv saved to ApproximatedForSingle\approx_entropy_patient_v58p_v58p.csv.csv
# Approximate Entropy results for Patient v59p_v59p.csv saved to ApproximatedForSingle\approx_entropy_patient_v59p_v59p.csv.csv
# Approximate Entropy results for Patient v60p_v60p.csv saved to ApproximatedForSingle\approx_entropy_patient_v60p_v60p.csv.csv
